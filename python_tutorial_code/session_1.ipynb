# %%
num_1 = 5

print(num_1)

num_1 = 5.0

num_2 = 10

answer = num_2 / num_1

answer_str = float(answer)

# int, integer
# str, string
# float

# * times
# / divide
# + plus
# - minus

type(answer_str)

var_1 = 43

var_2 = 64

answer = var_1 * var_2

answer
# Out:
# 5
# 2752

# %%
r = 2

pi = 3.14

area = pi * r **2

area
# Out:
# 12.56

# %%
name = "Lamin"
job = "Data Officer"

name_job = f"Hi my name is {name}, and I am a {job}."

name_job
# Out:
# 'Hi my name is Lamin, and I am a Data Officer.'

# %%
phrase = name_job

phrase
# Out:
# 'Hi my name is Lamin, and I am a Data Officer.'

# %%
num_1 = num_1 + 1

num_1
# Out:
# 6.0

# %%
phrase = name_job

phrase[8:12]

# iterate
# iterate over
# a thing that has parts that can be accessed one at a time
# counting in python starts at 0

# [start : stop]
# start is inclusive
# stop is exclusive

# to start format he right use a minus
# Out:
# 'me i'

# %%
phrase = name_job

phrase

# iterate
# iterate over
# a thing that has parts that can be accessed one at a time
# counting in python starts at 0
# Out:
# 'Hi my name is Lamin, and I am a Data Officer.'
